# %% [markdown]
# Deep Learning
# =============
#
# Assignment 6
# ------------
#
# After training a skip-gram model in `5_word2vec.ipynb`, the goal of this notebook is to train a LSTM character model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  with zipfile.ZipFile(filename) as f:
    name = f.namelist()[0]
    data = tf.compat.as_str(f.read(name))
  return data
  
text = read_data(filename)
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %% [markdown]
# Create a small validation set.

# %%
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %% [markdown]
# Utility functions to map characters to vocabulary IDs and back.

# %%
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
  if char in string.ascii_lowercase:
    return ord(char) - first_letter + 1
  elif char == ' ':
    return 0
  else:
    print('Unexpected character: %s' % char)
    return 0
  
def id2char(dictid):
  if dictid > 0:
    return chr(dictid + first_letter - 1)
  else:
    return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %% [markdown]
# Function to generate a training batch for the LSTM model.

# %%
batch_size=64
num_unrollings=10

class BatchGenerator(object):
  def __init__(self, text, batch_size, num_unrollings):
    self._text = text
    self._text_size = len(text)
    self._batch_size = batch_size
    self._num_unrollings = num_unrollings
    segment = self._text_size // batch_size
    self._cursor = [ offset * segment for offset in range(batch_size)]
    self._last_batch = self._next_batch()
  
  def _next_batch(self):
    """Generate a single batch from the current cursor position in the data."""
    batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
    for b in range(self._batch_size):
      batch[b, char2id(self._text[self._cursor[b]])] = 1.0
      self._cursor[b] = (self._cursor[b] + 1) % self._text_size
    return batch
  
  def next(self):
    """Generate the next array of batches from the data. The array consists of
    the last batch of the previous array, followed by num_unrollings new ones.
    """
    batches = [self._last_batch]
    for step in range(self._num_unrollings):
      batches.append(self._next_batch())
    self._last_batch = batches[-1]
    return batches

def characters(probabilities):
  """Turn a 1-hot encoding or a probability distribution over the possible
  characters back into its (most likely) character representation."""
  return [id2char(c) for c in np.argmax(probabilities, 1)]

def batches2string(batches):
  """Convert a sequence of batches back into their (most likely) string
  representation."""
  s = [''] * batches[0].shape[0]
  for b in batches:
    s = [''.join(x) for x in zip(s, characters(b))]
  return s

train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)

print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
  """Log-probability of the true labels in a predicted batch."""
  predictions[predictions < 1e-10] = 1e-10
  return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
  """Sample one element from a distribution assumed to be an array of normalized
  probabilities.
  """
  r = random.uniform(0, 1)
  s = 0
  for i in range(len(distribution)):
    s += distribution[i]
    if s >= r:
      return i
  return len(distribution) - 1

def sample(prediction):
  """Turn a (column) prediction into 1-hot encoded samples."""
  p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
  p[0, sample_distribution(prediction[0])] = 1.0
  return p

def random_distribution():
  """Generate a random column of probabilities."""
  b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
  return b/np.sum(b, 1)[:,None]

# %% [markdown]
# Simple LSTM Model.

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    print("i.shape:", i.shape)
    print("output.shape:", output.shape)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    conc_outputs = tf.concat(outputs, 0)
    logits = tf.nn.xw_plus_b(conc_outputs, w, b)
    print("conc_outputs.shape:", conc_outputs.shape)
    print("outputs.len:", len(outputs))
    print("logits.shape:", logits.shape)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
# Out:
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# i.shape: (64, 27)
# output.shape: (64, 64)
# conc_outputs.shape: (640, 64)
# outputs.len: 10
# logits.shape: (640, 27)

# %%
num_steps = 7001
summary_frequency = 1000

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    #print('batches[0].shape:', batches[0].shape)
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('predictions.shape:', predictions.shape)
      print('labels.shape:', labels.shape)
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 1) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.296779 learning rate: 10.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 27.03
# ================================================================================
# ym  yfykedy wuiwazgctrcnclswdhsvep oyimcxcgi jc erreeeowarmnaapvdmcf tntxaeqjxsp
# oxyubmet x rnmiia h pezgnw yudcvopoxxcuuaszorwr wxhvkifjc   jey mbamalpdt egmctr
#  aqdag ocrnakxrgiemspvfihzalnwtotftrls bo k  nca pekvlaciro esdtkwiqxdbhsyok v i
# nwr eksmiwx botrsdapb hwjcneffz f kpe  oh e kco u b xc z bk kai wjvcjin zidjte h
# newj llnzckeftcoprvah h y eae nsvidze hngiahm taatvssohoaxoxmrwroawdhtfhkdnl do
# ================================================================================
# Validation set perplexity: 20.30
# Average loss at step 1000: 2.012156 learning rate: 10.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 5.82
# ================================================================================
# mage spresian cesmenter tool  ore nine one seven oned equilsitional secour extor
# k the yeer heivhistflans is eres from zero one nine ans remable humber infofe fl
# gean iningations acreen seclustion moir nine is five sive in nation deacher cens
# rating execicr of enelly menin muce divive of inder the unibli p ches has proted
# gudeth in the caning hislheelhince of spite regrodd al eargater jlean three nine
# ================================================================================
# Validation set perplexity: 6.15
# Average loss at step 2000: 1.728986 learning rate: 10.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 5.66
# ================================================================================
# m midely spra mopthles world it of pecural tromuminalian dif rasistansogulal ain
# use as the cloz of chrresied in itsondersy spiding appacer constantyanchrei te s
# dia proging kind with in later and cauried or promital bejocces prodor doyzoudal
# lanal bays as andinsiture prograss andoanly a cituni to his one zero zemo and un
# lir hoving on peeral see becasion a caicate re toparchessal the med prosides dea
# ================================================================================
# Validation set perplexity: 5.18
# Average loss at step 3000: 1.666682 learning rate: 10.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 5.27
# ================================================================================
# metuh and billed reaald one one life grames by appeated theylorited gase figr ca
# vilutional a bewand macmprating calsion cland onlocally with accuration on one t
# nesers assocespood raophy isteral one six of the singles to dif of the velates t
# caltimal landacky vapers duristo decises hespeppels bos of tree suctor rare putu
# stand or runglible modical vidg expancas inclument one nine nine six four often
# ================================================================================
# Validation set perplexity: 4.77
# Average loss at step 4000: 1.651502 learning rate: 10.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 4.78
# ================================================================================
# zing where according zeeg it to extendence lat memberse armuaiation ged still fr
# neal under of the preeved todemat rilla master in same to gorbe demorrey betwing
# uding war applicibrise armengity with ascerpreted deflel doal peepional papitial
# feas mmysish first placies the underth places in during and obsond us americas t
# press seven diregatiun for shorames from sames show empeas of flata becomberriad
# ================================================================================
# Validation set perplexity: 4.56
# Average loss at step 5000: 1.624327 learning rate: 1.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 4.53
# ================================================================================
# quanked speal and danydesler the campleggs vificing years s he unjues win met cl
# ing reform one six zero nine two zero two minhed hid five is death is imavildren
# ons scound suen f by the world developre death creative electrive reacti end w i
# x contacted by ass active dividenginifot five nine he between b as it monned the
# ra the had a form oromems its an or biagn and populase herkean of last smally fu
# ================================================================================
# Validation set perplexity: 4.55
# Average loss at step 6000: 1.578943 learning rate: 1.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 4.87
# ================================================================================
# word hage one nine nine five seven gine a cut expirits in the bylex trabaics the
# rened marois the egbunate new their speepner in canfoutting and day of englard r
# als one nine sifn transt a che by goelted from the fead dus of eight four millio
# freors in the pose distruction example ig onliby with gaines or still sverk the
# has hos lize relaw spherit mescoundings howaso partius musing agreder of distrib
# ================================================================================
# Validation set perplexity: 4.25
# Average loss at step 7000: 1.568930 learning rate: 1.000000
# predictions.shape: (640, 27)
# labels.shape: (640, 27)
# Minibatch perplexity: 5.22
# ================================================================================
# hidaws havency asteries spitch science for the conailted and on the leges on ath
# k mahbross s began lankel and six shootly regations up ebabout and eighes and wa
# s pieter appligen davexelisatious with the derward code government of examerier
# k inclus rars to of cature accorded they infor the fillion the historical madali
# n one nine the side of mainve of and attloold iis an is new without of he weald
# ================================================================================
# Validation set perplexity: 4.22

# %% [markdown]
# ---
# Problem 1
# ---------
#
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications with the input, and 4 matrix multiplications with the output. Simplify the expression by using a single matrix multiply for each, and variables that are 4 times larger.
#
# ---

# %%
# https://github.com/ponderousmad/ud730/blob/master/6_lstm.ipynb

# %%
num_nodes = 64

graph = tf.Graph()
with graph.as_default():
  '''
  # Parameters:
  # Input gate: input, previous output, and bias.
  ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ib = tf.Variable(tf.zeros([1, num_nodes]))
  # Forget gate: input, previous output, and bias.
  fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  fb = tf.Variable(tf.zeros([1, num_nodes]))
  # Memory cell: input, state and bias.                             
  cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  cb = tf.Variable(tf.zeros([1, num_nodes]))
  # Output gate: input, previous output, and bias.
  ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
  om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
  ob = tf.Variable(tf.zeros([1, num_nodes]))
  '''

  gate_count = 4
  # Parameters:
  # Gates: input gate, forget gate, memory cell, and output gate.
  input_weights = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes * gate_count], -0.1, 0.1))
  output_weights = tf.Variable(tf.truncated_normal([num_nodes, num_nodes * gate_count], -0.1, 0.1))
  bias = tf.Variable(tf.zeros([1, num_nodes * gate_count]))
        
  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
  b = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
    Note that in this formulation, we omit the various connections between the
    previous state and the gates."""
    ''' 
    input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
    forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
    update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)    
    '''
    values = tf.split(axis=1, num_or_size_splits=gate_count, value=tf.matmul(i, input_weights) + tf.matmul(o, output_weights) + bias)
    
    input_gate = tf.sigmoid(values[0])
    forget_gate = tf.sigmoid(values[1])
    update = values[2]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(values[3])
    
    return output_gate * tf.tanh(state), state

  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.

  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))

  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))
  sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 1000

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
      labels = np.concatenate(list(batches)[1:])
      print('predictions.shape: ', predictions.shape)
      print('labels.shape: ', labels.shape)
        
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
      if step % (summary_frequency * 2) == 0:
        # Generate some samples.
        print('=' * 80)
        for _ in range(5):
          feed = sample(random_distribution())
          sentence = characters(feed)[0]
          reset_sample_state.run()
          for _ in range(79):
            prediction = sample_prediction.eval({sample_input: feed})
            feed = sample(prediction)
            sentence += characters(feed)[0]
          print(sentence)
        print('=' * 80)
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      for _ in range(valid_size):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        valid_logprob = valid_logprob + logprob(predictions, b[1])
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.297052 learning rate: 10.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 27.03
# ================================================================================
# tdhsevef iybiob iusivertrggusdiqkup nex fwoqvai  el etbnrobj a etavhueezhcba a n
# rxxjet kpvtdkul kf zo  bxoog  ieqtw ntutewsjafosnyilfvbfiy ryivp gpenokdufd uay
# bh axe  nxuupl   gcxvi kmteih qdebibf wdulwa grikij a d ftotqf  jergevgvq  ro vj
# n qa sydpx hvsejqiqvgve daqemx   o uumjhlvs glngwwl scljyz  eq ajjyhq wmfi teaar
# joxnycata  xf lm   he  v ae  estakycccrhh g  e y jwsihoueoepxekzacd oertknapnrdp
# ================================================================================
# Validation set perplexity: 20.03
# Average loss at step 1000: 2.019924 learning rate: 10.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 6.51
# Validation set perplexity: 5.99
# Average loss at step 2000: 1.734045 learning rate: 10.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 5.08
# ================================================================================
# pend longt be the preded cald plods the soch the ghesh back battucty luters a co
# me of beforued possitional phain plair hohe the s others and supenion lether mad
# nsus sar sears allowide lay strished offere loyers auveriam of truich commovacie
# warp phonem visetery toszal formantal continiett and the the buitt and forbly si
# con by one jeard best this national of intermize that he feestral ficlued diffic
# ================================================================================
# Validation set perplexity: 5.35
# Average loss at step 3000: 1.685248 learning rate: 10.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 4.89
# Validation set perplexity: 5.17
# Average loss at step 4000: 1.650138 learning rate: 10.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 5.58
# ================================================================================
# quess in curteg was ressu s metter the liftul prolops loughs vis an zero austras
# boxs asseven edits desect attending to of he add cleastry pnokech as armitry to
#  karts inurdat in namirs zero six eight emist clare see arterse adout noo cugism
# ogasia were and euro adawn lecher off was of belen rilive guikes dies invedsior
# man american the year city one eight nound attembely effectul by the mudibnays c
# ================================================================================
# Validation set perplexity: 4.83
# Average loss at step 5000: 1.618849 learning rate: 1.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 4.84
# Validation set perplexity: 4.81
# Average loss at step 6000: 1.586305 learning rate: 1.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 4.78
# ================================================================================
# a livelokal is vare computers and stateting consisuating which port sarists of t
# uts for zour who may larmera and poges in the active to allors aromatvonwingon b
# veration of the stroanmer blat four menica other board controllern kupror the ca
# g fundariouthys to schnole x lone to the meditian is declvion assume on of tratm
# es new network examplina hus for antwin in in derop a lodi jaw when corpbery the
# ================================================================================
# Validation set perplexity: 4.47
# Average loss at step 7000: 1.578254 learning rate: 1.000000
# predictions.shape:  (640, 27)
# labels.shape:  (640, 27)
# Minibatch perplexity: 5.03
# Validation set perplexity: 4.54

# %% [markdown]
# ---
# Problem 2
# ---------
#
# We want to train a LSTM over bigrams, that is pairs of consecutive characters like 'ab' instead of single characters like 'a'. Since the number of possible bigrams is large, feeding them directly to the LSTM using 1-hot encodings will lead to a very sparse representation that is very wasteful computationally.
#
# a- Introduce an embedding lookup on the inputs, and feed the embeddings to the LSTM cell instead of the inputs themselves.
#
# b- Write a bigram-based LSTM, modeled on the character LSTM above.
#
# c- Introduce Dropout. For best practices on how to use Dropout in LSTMs, refer to this [article](http://arxiv.org/abs/1409.2329).
#
# ---

# %%
unique_bigrams = vocabulary_size * vocabulary_size

def encode_bigram(characters):
    first = char2id(characters[0])
    second = (char2id(characters[1]) if len(characters) > 1 else 0)
    return first * vocabulary_size + second

def decode_bigram(bigram_id):
    second = bigram_id % vocabulary_size
    first = (bigram_id - second) // vocabulary_size
    return "".join([id2char(first), id2char(second)])

# this part seems not finished yet by the original author
class BigramBatchGenerator(object):
    def __init__(self, text, size, unrolls):
        self._text = text
        self._text_size = len(text)
        self._batch_size = size
        self._unrolls = unrolls
        segment = self._text_size // (2 * size)
        self._cursor = [offset * segment for offset in range(size)]
        self._last_batch = self._next_batch()
  
    def _next_batch(self):
        """Generate a single batch from the current cursor position in the data."""
        batch = np.zeros(shape=(self._batch_size), dtype=np.int)
        for b in range(self._batch_size):
            batch[b] = encode_bigram(self._text[self._cursor[b]:self._cursor[b] + 2])
            self._cursor[b] = (self._cursor[b] + 2) % self._text_size
        return batch
  
    def next(self):
        """Generate the next array of batches from the data. The array consists of
        the last batch of the previous array, followed by num_unrollings new ones.
        """
        batches = [self._last_batch]
        for step in range(self._unrolls):
            batches.append(self._next_batch())
        self._last_batch = batches[-1]
        return batches

def bigrams(encoded_bigrams):
    """Turn encoded bigrams back into its (most likely) character representation."""
    return [decode_bigram(int(b)) for b in encoded_bigrams]

def bibatches2string(batches):
    """Convert a sequence of batches back into their (most likely) string
    representation."""
    s = [''] * batches[0].shape[0]
    for b in batches:
        s = [''.join(x) for x in zip(s, bigrams(b))]
    return s

# %%
print(train_text[:30])

bigram_batches = BigramBatchGenerator(train_text, 5, 10)

print(bibatches2string(bigram_batches.next()))
print(bibatches2string(bigram_batches.next()))
print(bibatches2string(bigram_batches.next()))
print(bibatches2string(bigram_batches.next()))
# Out:
# ons anarchists advocate social
# ['ons anarchists advocat', 'nts and release day ev', 'y eight inch two zero ', 'one nine seven zero s ', 'o two one nine zero th']
# ['ate social relations b', 'events apple has gener', 'o three mm of armour s', 's because in winter th', 'three publ one nine on']
# [' based upon voluntary ', 'erally chosen to stick', ' survived hits from on', 'the canal freezes befo', 'one three p seven two ']
# ['y association of auton', 'ck with some loose use', 'one five inch three ei', 'fore the lakes and the', 'o zero on dark matter ']

# %%
num_nodes = 64
bigrams_vsize = vocabulary_size * vocabulary_size
embedding_vsize = 36

def sample_vsize():
  v = np.zeros(shape=(1), dtype=np.int)
  v[0] = random.randint(0,  bigrams_vsize- 1)
  return v

graph = tf.Graph()
with graph.as_default():

  gate_count = 4
  # Parameters:
  embeddings = tf.Variable(tf.random_uniform([bigrams_vsize, embedding_vsize], -0.1, 0.1))

  # Gates: input gate, forget gate, memory cell, and output gate.
  input_weights = tf.Variable(tf.truncated_normal([embedding_vsize, num_nodes * gate_count], -0.1, 0.1))
  output_weights = tf.Variable(tf.truncated_normal([num_nodes, num_nodes * gate_count], -0.1, 0.1))
  bias = tf.Variable(tf.zeros([1, num_nodes * gate_count]))

  print("input_weights.shape:", input_weights)
  print("output_weights.shape:", output_weights)
  print("bias.shape:", bias)


  # Variables saving state across unrollings.
  saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
  # Classifier weights and biases.
  w = tf.Variable(tf.truncated_normal([num_nodes, embedding_vsize], -0.1, 0.1))
  b = tf.Variable(tf.zeros([embedding_vsize]))
  
  # Definition of the cell computation.
  def lstm_cell(i, o, state):
    values = tf.split(axis=1, num_or_size_splits=gate_count, value=tf.matmul(i, input_weights) + tf.matmul(o, output_weights) + bias)
    
    input_gate = tf.sigmoid(values[0])
    forget_gate = tf.sigmoid(values[1])
    update = values[2]
    state = forget_gate * state + input_gate * tf.tanh(update)
    output_gate = tf.sigmoid(values[3])
    
    return output_gate * tf.tanh(state), state

  """
  # Input data.
  train_data = list()
  for _ in range(num_unrollings + 1):
    train_data.append(
      tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
  train_inputs = train_data[:num_unrollings]
  train_labels = train_data[1:]  # labels are inputs shifted by one time step.  
  """

  # Input data.
  train_data = list()
  train_embeddings = list()
  for _ in range(num_unrollings + 1):
    train_data.append(tf.placeholder(tf.int32, shape=[batch_size]))
    train_embeddings.append(tf.nn.embedding_lookup(embeddings, train_data[-1]))
  
  train_inputs = train_embeddings[:num_unrollings]
  train_labels = train_embeddings[1:]  # labels are inputs shifted by one time step.


  # Unrolled LSTM loop.
  outputs = list()
  output = saved_output
  state = saved_state
  for i in train_inputs:
    output, state = lstm_cell(i, output, state)
    outputs.append(output)

  # State saving across unrollings.
  with tf.control_dependencies([saved_output.assign(output),
                                saved_state.assign(state)]):
    # Classifier.
    logits = tf.nn.xw_plus_b(tf.concat(outputs, 0), w, b)
    loss = tf.reduce_mean(
      tf.nn.softmax_cross_entropy_with_logits(
        labels=tf.concat(train_labels, 0), logits=logits))


  # Optimizer.
  global_step = tf.Variable(0)
  learning_rate = tf.train.exponential_decay(
    10.0, global_step, 5000, 0.1, staircase=True)
  optimizer = tf.train.GradientDescentOptimizer(learning_rate)
  gradients, v = zip(*optimizer.compute_gradients(loss))
  gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
  optimizer = optimizer.apply_gradients(
    zip(gradients, v), global_step=global_step)

  # Predictions.
  train_prediction = tf.nn.softmax(logits)
  print("train_prediction.shape:", train_prediction.shape)

  embedding_norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  embedding_normalized = embeddings / embedding_norm

  # Compute the similarity between validation examples and all embeddings using cosine distance:
  valid_dataset = tf.constant( np.array(range(bigrams_vsize)), dtype=tf.int32)
  valid_embeddings = tf.nn.embedding_lookup(embedding_normalized, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(embedding_normalized))

    
  # Sampling and validation eval: batch 1, no unrolling.
  sample_input = tf.placeholder(tf.int32, shape=[1])
  saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
  saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
  reset_sample_state = tf.group(
    saved_sample_output.assign(tf.zeros([1, num_nodes])),
    saved_sample_state.assign(tf.zeros([1, num_nodes])))

  sample_embedding = tf.nn.embedding_lookup(embeddings, sample_input)
  sample_output, sample_state = lstm_cell(
    sample_embedding, saved_sample_output, saved_sample_state)
  with tf.control_dependencies([saved_sample_output.assign(sample_output),
                                saved_sample_state.assign(sample_state)]):
    sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))
    print("sample_prediction.shape:", sample_prediction.shape)
# Out:
# input_weights.shape: Tensor("Variable_1/read:0", shape=(36, 256), dtype=float32)
# output_weights.shape: Tensor("Variable_2/read:0", shape=(64, 256), dtype=float32)
# bias.shape: Tensor("Variable_3/read:0", shape=(1, 256), dtype=float32)
# train_prediction.shape: (640, 36)
# sample_prediction.shape: (1, 36)

# %%
train_batches = BigramBatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BigramBatchGenerator(valid_text, 1, 1)

num_steps = 7001
summary_frequency = 1000


with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  mean_loss = 0
  for step in range(num_steps):
    batches = train_batches.next()
    feed_dict = dict()
    for i in range(num_unrollings + 1):
      feed_dict[train_data[i]] = batches[i]
    _, l, predictions, lr = session.run(
      [optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
    mean_loss += l
    if step % summary_frequency == 0:
      if step > 0:
        mean_loss = mean_loss / summary_frequency
      # The mean loss is an estimate of the loss over the last few batches.
      print(
        'Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
      mean_loss = 0
    
      #labels = np.concatenate(list(batches)[1:]) 
      # we need to call lookup embedding to figure out the labels
      new_batches = list()
      for batch in list(batches)[1:]:
        #batch = np.zeros(shape=(batch_size), dtype=np.int)
        #new_batch = np.zeros(shape=(batch_size, embedding_vsize), dtype=np.int)
        new_batch = tf.nn.embedding_lookup(embeddings, batch)
        new_batches.append( new_batch.eval() )
      labels = np.concatenate(list(new_batches)) 
    
      print('predictions.shape: ', predictions.shape)
      print('labels.shape: ', labels.shape)
        
      print('Minibatch perplexity: %.2f' % float(
        np.exp(logprob(predictions, labels))))
    
      if step % (summary_frequency) == 0:
        # Generate some samples.
        sim = similarity.eval()
        print('=' * 45)
        for _ in range(5):
          feed = sample_vsize()
          sentence = decode_bigram(feed) #"_init_"
          reset_sample_state.run()
          for _ in range(20):
            prediction = sample_prediction.eval({sample_input: feed})
            st = (-sim[feed[0], :]).argsort()
            top_K = 5
            nearest = st[1:top_K+1]
            s_id = random.randint(0,  top_K-1)
            sentence += decode_bigram( nearest[s_id] )
            feed[0] = s_id
            
            # we should sample next value for feed
            #print("s_id:", s_id)
            
          print(sentence)
        print('=' * 45)
    
      # Measure validation set perplexity.
      reset_sample_state.run()
      valid_logprob = 0
      dbg = 0
      for _ in range(50):
        b = valid_batches.next()
        predictions = sample_prediction.eval({sample_input: b[0]})
        expect = tf.nn.embedding_lookup(embeddings, b[1])
        # very expensive operation
        expect_val = expect.eval() 
        valid_logprob = valid_logprob + logprob(predictions, expect_val )
        
      print('Validation set perplexity: %.2f' % float(np.exp(
        valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 0.108175 learning rate: 10.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.39
# =============================================
# nqvoqliszzbtbq hznznzzja y scqisqtpqepkbpq
# aixcujabbq hzzbq hznznzzbqzqqlcqcqcqisznzn
# uair hujkk nbtep siszzepjrzze cqabbte fdpq
# oigobtep sabbtbte kkjrqt hqt hznzzja ykbzq
# yfjx y ne fdzqpqbtjaujfdzfjrzn ykbzqqlfdzq
# =============================================
# Validation set perplexity: 0.96
# Average loss at step 1000: -22.784611 learning rate: 10.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# yakme fdofe fdsengononheng oe kkon o s acq
# kcbcan tsean skk scqfdngheofonve oone kk t
# ezvkhye hyve i i ove i oe cqabhese acqhy a
# rsomab ionin sanine fd acqabtihye fdofonon
# hay onon iheof a t ahy aine kkon ovetikkon
# =============================================
# Validation set perplexity: 0.23
# Average loss at step 2000: -23.137964 learning rate: 10.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# quar acqab i i oone fdofonone fdngtihye kk
# oyaongheofe kk tse ahy s ahy sof a tofve o
# vgtmngtifd aab iticqkkine kkon i i oonon a
# cbubkkon oveheng iheaninveticqhyonone fdse
# wysc tng i oonve oe cqfdnghean skkhe tsean
# =============================================
# Validation set perplexity: 0.31
# Average loss at step 3000: -22.942581 learning rate: 10.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# ftmn s afdofe kkheon oonon sse aab ove ihe
# suipkkontiab iheanheon oe kkheontifdanine
# am aseng ovehe aabhe ahy ssenghesengheanhe
# wbxpseofone cqfd aabtikkheon ihesengonon i
# kk   shyve i ove itikkin ahein aheon oone
# =============================================
# Validation set perplexity: 0.34
# Average loss at step 4000: -23.040658 learning rate: 10.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# kesmse acqcqcqkk scqabtihy ssese akkhehe t
#   kkon itikkhe tng itiabhe ahy a tofe cqhy
# cdpqheofone kk tofone hyonon sofon ainveon
# mgc  ain sanhe tseseng o a tan t ahy sseng
# ktsftihy s akkine fdseofonon sofone kk tof
# =============================================
# Validation set perplexity: 0.37
# Average loss at step 5000: -22.904466 learning rate: 1.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# pvyu ihengheofvehengticqfdanheonhe akk t a
# ezvkabhe acqfdse ahye cqfdan tanon ionhe t
# cvxqhye cqabtihy a scqhyon sofonve iononon
# axmwhy s acqkk sab o san tng ionheon ihean
#  dveon skk sfdofon s aabheofe hy aheheon i
# =============================================
# Validation set perplexity: 0.28
# Average loss at step 6000: -16.240687 learning rate: 1.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# rqjbhy aheonhengon t aabonon oveheofvetiab
# xrwrab oe ab ion tsenghengtikk tngheofone
# inon sfdof aononhehe t akkin sngtiabonheon
# luirnghese ahy sofone fd akkheontikk tan t
# nkuoine cqabticqhyononon ahe taninon a tse
# =============================================
# Validation set perplexity: 0.45
# Average loss at step 7000: -16.184926 learning rate: 1.000000
# predictions.shape:  (640, 36)
# labels.shape:  (640, 36)
# Minibatch perplexity: 0.00
# =============================================
# sdvftiabon tngticqcqkk shyve oe cqcqabtikk
# uznze hyvetihyveonine abheng oveheof a t a
# qfpx afd ahyononone hyve ionhe scqhye abhe
# fwzgon o ainon aon oe kkheinonon s acqfdof
# filt a sfdngtikkinononon ainonve ion sfd a
# =============================================
# Validation set perplexity: 0.42

# %% [markdown]
# ---
# Problem 3
# ---------
#
# (difficult!)
#
# Write a sequence-to-sequence LSTM which mirrors all the words in a sentence. For example, if your input is:
#
#     the quick brown fox
#
# the model should attempt to output:
#
#     eht kciuq nworb xof
#
# Refer to the lecture on how to put together a sequence-to-sequence model, as well as [this article](http://arxiv.org/abs/1409.3215) for best practices.
#
# ---
